# %%
num = 10

# if문
if num == 10:
    print('참')

# if ~ else 문
num = int(input("정수입력:"))

if num % 2 == 0:
    print("짝수")
else:
    print("홀수")

if 80 <= num < 90 == 0:
    print("짝수")
else:
    print("축하합니다. 당신은 재수강입니다.")
# 
s = input("continue(Y/n)?")

if s == y or s == Y:
    print("Go!")
else:
    print('stop!')

# 또 다른 형태의 if else 문
x = int(input("첫번쨰 수 : "))
y = int(input("두번쨰 수 : "))

max1 =(x if x > y else y)
min1 = (y if x > y else x)

print("큰 수 = %d, 작은 수 = %d" %(max1, min1))

# elif
x = int(input('첫 번쨰 수 ='))
y = int(input('두 번쨰 수 = '))

if x > y:
    print("큰수 %d, 작은 수 %d" %(x, y))

elif x < y:
    print("큰수 = %d, 작은 수 %d" %(y, x))

elif x == y:
    print("두 수는 같다.")

# if else elif
jumsu = int(input("점수 입력 : "))

if jumsu >= 90:
    print("학점 A")
elif jumsu >= 80:
    print("학점 B")
elif jumsu >= 70:
    print("학점 C")
elif jumsu >= 60:
    print("학점 D")

else:
    print("학점 F")

# 중첩 if문
jumsu = int(input("점수 입력: "))

if jumsu >= 80:
    if jumsu >= 90:
        print("장학금 대상입니다.")
    else:
        print("좀 치네??")

else:
    print("걍 재수강 ㄱㄱ")

# %%
# map ()
a, b = input('문자열 두개를 입력하시요 : ').split()
print(a + b)

a, b = map(int, input().split())
print(a + b)

a, b = map(float, input().split())
print(a + b)

# 
a, b, c = map(int, input("세 변의 길이를 쓰시오").split())

if a + b <= c or a+c <= b or b+c <= a or a <= 0 or b <= 0 or c <=0:
    print("삼각형이 아닙니다")

elif a == b or b == c:
    print("정 삼각형")

elif a == b or a == c or c == b:
    print("이등변 삼각형")

elif a**2 + b**2 == c**2 or b**2 + c**2 == a**2 or a**2 + c**2 == b**2:
    print("직각 삼각형")

else:
    print("일반 삼각형")
# 
import random

computer = random.randint(0, 2)


while True:
    user  = int(input("0: 가위, 1 : 바위, 보 : 2 == "))
    if user >= 0 and user <= 2:
        break

if (user + 1) % 3 == computer:
    print("컴퓨터 승리")
elif user == computer:
    print("비김")
else:
    print("사용자 승리")

# 137쪽 연습문제  :: 6번, 11번, 13번

# %%
a, b, c = map(int, input("세 변의 길이를 쓰시오").split())

if a + b <= c or a+c <= b or b+c <= a or a <= 0 or b <= 0 or c <=0:
    print("삼각형이 아닙니다")

elif a == b or b == c:
    print("정 삼각형")

elif a == b or a == c or c == b:
    print("이등변 삼각형")

elif a**2 + b**2 == c**2 or b**2 + c**2 == a**2 or a**2 + c**2 == b**2:
    print("직각 삼각형")

else:
    print("일반 삼각형")

# %%
import random

computer = random.randint(0, 2)


while True:
    user  = int(input("0: 가위, 1 : 바위, 보 : 2 == "))
    if user >= 0 and user <= 2:
        break

if (user + 1) % 3 == computer:
    print("컴퓨터 승리")
elif user == computer:
    print("비김")
else:
    print("사용자 승리")

# 137쪽 연습문제  :: 6번, 11번, 13번
